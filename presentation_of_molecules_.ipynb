# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamedzaghloul-lab638/rdkit-tips-and-tricks-/blob/main/presentation_of_molecules_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install rdkit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.7/36.7 MB 49.3 MB/s eta 0:00:00
# ...

# %%
from rdkit import Chem , DataStructs
from rdkit.Chem import AllChem , Draw

# %%
suppl=Chem.SDMolSupplier('/content/PubChem_search_records.sdf')
mols= [x for x in suppl if x is not None]
for m in mols:
  AllChem.Compute2DCoords(m)
Draw.MolsToGridImage(mols , subImgSize=(400,400))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1200x15600>

# %%
suppl=Chem.SDMolSupplier('/content/PubChem_search_records.sdf')
mols= [x for x in suppl if x is not None]
for m in mols:
  AllChem.Compute2DCoords(m)
Draw.MolToFile(mols[0], r'E:\rdkit\img0.png')
Draw.MolToFile(mols[1], r'E:\rdkit\img1.png')

# %%
for i,m in enumerate(mols):
 Draw.MolToFile(m, f'/content/img_{i}.png')
